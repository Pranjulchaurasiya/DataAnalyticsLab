# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjulchaurasiya/DataAnalyticsLab/blob/main/DALAB_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
# Sample Houses dataset
data = {
    'Price': [250000, 180000, 300000, 275000, 200000],
    'Area': [2000, 1500, 2500, 2100, 1600],
    'Bedrooms': [3, 2, 4, 3, 2],
    'Bathrooms': [2, 1, 3, 2, 1],
    'Age': [10, 15, 5, 12, 20]
}

df = pd.DataFrame(data)

print("Original Data:\n", df)
# Out:
# Original Data:
#      Price  Area  Bedrooms  Bathrooms  Age
# 0  250000  2000         3          2   10
# 1  180000  1500         2          1   15
# 2  300000  2500         4          3    5
# 3  275000  2100         3          2   12
# 4  200000  1600         2          1   20

# %%
# Standardization
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# Apply PCA
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)

# Create DataFrame
pca_df = pd.DataFrame(pca_data, columns=['PC1', 'PC2'])

print("\nPCA Result:\n", pca_df)

# Explained variance
print("\nExplained Variance Ratio:", pca.explained_variance_ratio_)
# Out:
# PCA Result:
#          PC1       PC2
# 0  0.613174 -0.238165
# 1 -2.348153 -0.603200
# 2  3.378304 -0.120546
# 3  0.812270  0.458689
# 4 -2.455594  0.503221
#
# Explained Variance Ratio: [0.95969873 0.03594922]

# %%
# Plot
plt.scatter(pca_df['PC1'], pca_df['PC2'])
plt.title("PCA on Houses Dataset")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()
