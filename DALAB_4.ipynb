# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjulchaurasiya/DataAnalyticsLab/blob/main/DALAB_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics

# %%
# Taking input from user
data = list(map(float, input("Enter numbers separated by space: ").split()))
# Out:
# Enter numbers separated by space: 2 3 4 5  6 7 9 10

# %%
# Calculations
mean = statistics.mean(data)
median = statistics.median(data)

try:
    mode = statistics.mode(data)
except:
    mode = "No unique mode"

stdev = statistics.stdev(data)

# %%
# Output
print("Mean:", mean)
print("Median:", median)
print("Mode:", mode)
print("Standard Deviation:", stdev)
# Out:
# Mean: 5.75
# Median: 5.5
# Mode: 2.0
# Standard Deviation: 2.8157719063467175
