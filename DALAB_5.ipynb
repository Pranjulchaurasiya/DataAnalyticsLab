# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjulchaurasiya/DataAnalyticsLab/blob/main/DALAB_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
# Sample dataset with missing values
data = {
    'Age': [25, np.nan, 30, 22],
    'Salary': [50000, 60000, np.nan, 45000]
}

df = pd.DataFrame(data)

print("Original Data:\n", df)
# Out:
# Original Data:
#      Age   Salary
# 0  25.0  50000.0
# 1   NaN  60000.0
# 2  30.0      NaN
# 3  22.0  45000.0

# %%
# Handling missing values using mean
df.fillna(df.mean(), inplace=True)
print("\nAfter Handling Missing Values:\n", df)
# Out:
# After Handling Missing Values:
#           Age        Salary
# 0  25.000000  50000.000000
# 1  25.666667  60000.000000
# 2  30.000000  51666.666667
# 3  22.000000  45000.000000

# %%
# Min-Max Normalization
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df)

print("\nNormalized Data:\n", df_scaled)
# Out:
# Normalized Data:
#  [[0.375      0.33333333]
#  [0.45833333 1.        ]
#  [1.         0.44444444]
#  [0.         0.        ]]
