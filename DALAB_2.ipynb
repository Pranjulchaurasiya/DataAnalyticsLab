# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranjulchaurasiya/DataAnalyticsLab/blob/main/DALAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e32437f6-9a8f-434d-9829-bb41806310a4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e32437f6-9a8f-434d-9829-bb41806310a4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("train_schedulenew.csv")

# %%
df.head()
# Out:
#    Train ID         Train Name Station Code    Station Name Arrival Time  \
# 0       101       Jan Shatabdi          CNB          Kanpur        16:45
# 1       102  Intercity Express          CNB          Kanpur        14:00
# 2       103      Freight Goods          LKO         Lucknow        09:45
# 3       104      Freight Goods          SBC  Bengaluru City        20:45
# 4       105  Intercity Express          HWH          Howrah        20:45
#
#   Departure Time    Track Platform     Status Priority
# 0          18:00  Track 2      PF2    On Time   Medium
# 1          14:15  Track 1      PF1  Cancelled     High
# 2          11:45  Track 1      PF3    At-Risk     High
# 3          20:15  Track 3      PF4  Cancelled      Low
# 4          21:00  Track 2      PF4    Delayed   Medium

# %%
df.shape
# Out:
# (100, 10)

# %%
import matplotlib.pyplot as plt

# %%
print(df.columns)
# Out:
# Index(['Train ID', 'Train Name', 'Station Code', 'Station Name',
#        'Arrival Time', 'Departure Time', 'Track', 'Platform', 'Status',
#        'Priority'],
#       dtype='object')

# %%
df["Station Name"].value_counts().head(10).plot(kind="bar")
plt.title("Top 10 Busiest Source Stations")
plt.xlabel("Station")
plt.ylabel("Number of Trains")
plt.xticks(rotation=45)
plt.show()

# %%
df.to_csv("exported_file.csv",index=False)
